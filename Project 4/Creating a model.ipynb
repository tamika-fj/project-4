# %%
# Import the modules
import numpy as np
import pandas as pd
from pathlib import Path
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.preprocessing import LabelEncoder
from sklearn import tree
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import joblib

# %%
# Read the CSV file from the Resources folder into a Pandas DataFrame
diabetes_data_df = pd.read_csv(
    Path('Resources/cleaned_diabetes_df.csv')   
)

# Review the DataFrame
diabetes_data_df
# Out:
#      Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0        148             72             35      125  33.6
# 1         85             66             29      125  26.6
# 2        183             64             29      125  23.3
# 3         89             66             23       94  28.1
# 4        137             40             35      168  43.1
# ..       ...            ...            ...      ...   ...
# 763      101             76             48      180  32.9
# 764      122             70             27      125  36.8
# 765      121             72             23      112  26.2
# 766      126             60             29      125  30.1
# 767       93             70             31      125  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome BloodPressureRange GlucoseRange  \
# 0                       0.627   50        1           Elevated  Prediabetic
# 1                       0.351   31        0             Normal       Normal
# 2                       0.672   32        1             Normal  Prediabetic
# 3                       0.167   21        0             Normal       Normal
# 4                       2.288   33        1                Low       Normal
# ..                        ...  ...      ...                ...          ...
# 763                     0.171   63        0           Elevated       Normal
# 764                     0.340   27        0           Elevated       Normal
# 765                     0.245   30        0           Elevated       Normal
# 766                     0.349   47        1             Normal       Normal
# 767                     0.315   23        0           Elevated       Normal
#
#               BMIRange
# 0      Obesity Class I
# 1           Overweight
# 2        Normal Weight
# 3           Overweight
# 4    Obesity Class III
# ..                 ...
# 763    Obesity Class I
# 764   Obesity Class II
# 765         Overweight
# 766    Obesity Class I
# 767    Obesity Class I
#
# [768 rows x 11 columns]

# %%
# Define a mapping dictionary for each categorical feature
bp_mapping = {"Low": 0, "Normal": 1, "Elevated": 2, "High Stage 1": 3, "High Stage 2": 4}
glucose_mapping = {"Normal": 0, "Prediabetic": 1, "Diabetic": 2}
bmi_mapping = {"Normal Weight": 0, "Overweight": 1, "Obesity Class I": 2, "Obesity Class II": 3, "Obesity Class III": 4}

# Map the categories to numerical values
diabetes_data_df['EncodedBP'] = diabetes_data_df['BloodPressureRange'].map(bp_mapping)
diabetes_data_df['EncodedGlucose'] = diabetes_data_df['GlucoseRange'].map(glucose_mapping)
diabetes_data_df['EncodedBMI'] = diabetes_data_df['BMIRange'].map(bmi_mapping)

diabetes_data_df.head()
# Out:
#    Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0      148             72             35      125  33.6
# 1       85             66             29      125  26.6
# 2      183             64             29      125  23.3
# 3       89             66             23       94  28.1
# 4      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome BloodPressureRange GlucoseRange  \
# 0                     0.627   50        1           Elevated  Prediabetic
# 1                     0.351   31        0             Normal       Normal
# 2                     0.672   32        1             Normal  Prediabetic
# 3                     0.167   21        0             Normal       Normal
# 4                     2.288   33        1                Low       Normal
#
#             BMIRange  EncodedBP  EncodedGlucose  EncodedBMI
# 0    Obesity Class I        2.0               1         2.0
# 1         Overweight        1.0               0         1.0
# 2      Normal Weight        1.0               1         0.0
# 3         Overweight        1.0               0         1.0
# 4  Obesity Class III        0.0               0         4.0

# %%
# Add an identifying column
diabetes_data_with_index = diabetes_data_df.reset_index()
diabetes_data_with_index = diabetes_data_with_index.rename(columns={"index": "id"})
diabetes_data_with_index.head()
# Out:
#    id  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0   0      148             72             35      125  33.6
# 1   1       85             66             29      125  26.6
# 2   2      183             64             29      125  23.3
# 3   3       89             66             23       94  28.1
# 4   4      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome BloodPressureRange GlucoseRange  \
# 0                     0.627   50        1           Elevated  Prediabetic
# 1                     0.351   31        0             Normal       Normal
# 2                     0.672   32        1             Normal  Prediabetic
# 3                     0.167   21        0             Normal       Normal
# 4                     2.288   33        1                Low       Normal
#
#             BMIRange  EncodedBP  EncodedGlucose  EncodedBMI
# 0    Obesity Class I        2.0               1         2.0
# 1         Overweight        1.0               0         1.0
# 2      Normal Weight        1.0               1         0.0
# 3         Overweight        1.0               0         1.0
# 4  Obesity Class III        0.0               0         4.0

# %%
#Export to csv file 
output_file_path= Path('Resources/diabetes_data_with_index.csv') 
diabetes_data_with_index.to_csv(output_file_path, index=False)

# %%
#Drop the Range columns 
diabetes_data_df.drop(columns=["BloodPressureRange", "GlucoseRange", "BMIRange"], inplace=True)
diabetes_data_df.head()
# Out:
#    Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0      148             72             35      125  33.6
# 1       85             66             29      125  26.6
# 2      183             64             29      125  23.3
# 3       89             66             23       94  28.1
# 4      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome  EncodedBP  EncodedGlucose  \
# 0                     0.627   50        1        2.0               1
# 1                     0.351   31        0        1.0               0
# 2                     0.672   32        1        1.0               1
# 3                     0.167   21        0        1.0               0
# 4                     2.288   33        1        0.0               0
#
#    EncodedBMI
# 0         2.0
# 1         1.0
# 2         0.0
# 3         1.0
# 4         4.0

# %%
#Export to csv file 
output_file_path= Path('Resources/diabetes_data_df.csv') 
diabetes_data_df.to_csv(output_file_path, index=False)

# %%
diabetes_data_df.dropna(subset=["EncodedBP", "EncodedBMI"], inplace=True)
diabetes_data_df.reset_index(drop=True, inplace=True)

diabetes_data_df
# Out:
#      Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0        148             72             35      125  33.6
# 1         85             66             29      125  26.6
# 2        183             64             29      125  23.3
# 3         89             66             23       94  28.1
# 4        137             40             35      168  43.1
# ..       ...            ...            ...      ...   ...
# 746      101             76             48      180  32.9
# 747      122             70             27      125  36.8
# 748      121             72             23      112  26.2
# 749      126             60             29      125  30.1
# 750       93             70             31      125  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome  EncodedBP  EncodedGlucose  \
# 0                       0.627   50        1        2.0               1
# 1                       0.351   31        0        1.0               0
# 2                       0.672   32        1        1.0               1
# 3                       0.167   21        0        1.0               0
# 4                       2.288   33        1        0.0               0
# ..                        ...  ...      ...        ...             ...
# 746                     0.171   63        0        2.0               0
# 747                     0.340   27        0        2.0               0
# 748                     0.245   30        0        2.0               0
# 749                     0.349   47        1        1.0               0
# 750                     0.315   23        0        2.0               0
#
#      EncodedBMI
# 0           2.0
# 1           1.0
# 2           0.0
# 3           1.0
# 4           4.0
# ..          ...
# 746         2.0
# 747         3.0
# 748         1.0
# 749         2.0
# 750         2.0
#
# [751 rows x 11 columns]

# %%
median_values = diabetes_data_df.median()
median_values
# Out:
# Glucose                     117.000
# BloodPressure                72.000
# SkinThickness                29.000
# Insulin                     125.000
# BMI                          32.300
# DiabetesPedigreeFunction      0.378
# Age                          29.000
# Outcome                       0.000
# EncodedBP                     2.000
# EncodedGlucose                0.000
# EncodedBMI                    2.000
# dtype: float64

# %%
# Separate the data into labels and features

# Separate the y variable, the labels
y= diabetes_data_df["Outcome"]


# Separate the X variable, the features
x = diabetes_data_df.drop(columns="Outcome")

# %%
# Review the y variable Series
y[:5]
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    1
# Name: Outcome, dtype: int64

# %%
# Review the X variable DataFrame
x[:5]
# Out:
#    Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0      148             72             35      125  33.6
# 1       85             66             29      125  26.6
# 2      183             64             29      125  23.3
# 3       89             66             23       94  28.1
# 4      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  EncodedBP  EncodedGlucose  EncodedBMI
# 0                     0.627   50        2.0               1         2.0
# 1                     0.351   31        1.0               0         1.0
# 2                     0.672   32        1.0               1         0.0
# 3                     0.167   21        1.0               0         1.0
# 4                     2.288   33        0.0               0         4.0

# %%
# Import the train_test_learn module
from sklearn.model_selection import train_test_split

# Split the data using train_test_split
# Assign a random_state of 1 to the function
x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=1)

# %%
# Import the LogisticRegression module from SKLearn
from sklearn.linear_model import LogisticRegression

# Instantiate the Logistic Regression model
# Assign a random_state parameter of 1 to the model
logistic_regression_model = LogisticRegression(max_iter=1000, random_state=1)

# Fit the model using training data
lr_model = logistic_regression_model.fit(x_train, y_train)

# %%
# Make a prediction using the testing data
testing_predictions = logistic_regression_model.predict(x_test)

# %%
# Generate a confusion matrix for the model
test_matrix = confusion_matrix(y_test, testing_predictions)
# Print the confusion matrix for the testing data
print(test_matrix)
# Out:
# [[103  19]
#  [ 32  34]]

# %%
# Print the classification report for the model
# Create and save the training classification report
testing_report = classification_report(y_test, testing_predictions)

# Print the training classification report
print(testing_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.84      0.80       122
#            1       0.64      0.52      0.57        66
#
#     accuracy                           0.73       188
#    macro avg       0.70      0.68      0.69       188
# weighted avg       0.72      0.73      0.72       188

# %%
joblib.dump(lr_model, "diabetes_predictor.joblib")
# Out:
# ['diabetes_predictor.joblib']
